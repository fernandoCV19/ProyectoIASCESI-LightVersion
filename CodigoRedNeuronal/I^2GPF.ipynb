# %%
import sys
import os
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras import optimizers
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dropout, Flatten, Dense, Activation, Convolution2D, MaxPooling2D
from tensorflow.python.keras import backend as K
from tensorflow.python.framework.ops import disable_eager_execution

disable_eager_execution()

# %%
#Colcar la direccion de memoria donde se encuentra el dataset de entrenamiento y de validacion correspondientemente.
K.clear_session()
data_entrenamiento = ''
data_validacion = ''

# %%
#parametros
epocas = 25
batch_size = 75
pasos = 60
pasos_validacion = 15
clases = 2
lr = 0.0005

# %%
#Preprocesamiento de imagenes y ampliacion del dataset
entrenamiento_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.3,
    width_shift_range=.15,
    height_shift_range=.15,
    zoom_range = 0.3,
    horizontal_flip = True,
)

validacion_datagen = ImageDataGenerator(
    rescale = 1./255,
)

imagen_entrenamiento = entrenamiento_datagen.flow_from_directory(
    data_entrenamiento,
    shuffle = True,
    target_size = (100,100),
    batch_size = batch_size,
    class_mode = 'categorical'
)

imagen_validacion = validacion_datagen.flow_from_directory(
    data_validacion,
    target_size = (100,100),
    batch_size = batch_size,
    class_mode = 'categorical'
)
# Out:
# Found 1298 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.

# %%
# Red neuronal 
cnn = Sequential()

cnn.add(Convolution2D(16,(3,3), padding='same',input_shape=(100,100,3),activation='relu'))

cnn.add(MaxPooling2D(pool_size= (2,2)))

cnn.add(Dropout(0.2))

cnn.add(Convolution2D(32,(3,3), padding='same',activation='relu'))

cnn.add(MaxPooling2D(pool_size= (2,2)))

cnn.add(Convolution2D(64,(3,3), padding='same',activation='relu'))

cnn.add(MaxPooling2D(pool_size= (2,2)))

cnn.add(Dropout(0.2))

cnn.add(Flatten())

cnn.add(Dense(512, activation='relu', ))

cnn.add(Dropout(0.5))

cnn.summary()

cnn.add(Dense(clases, activation= 'softmax'))

cnn.compile(loss='categorical_crossentropy', optimizer = optimizers.Adam(lr = lr), metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 50, 50, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               4719104
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# =================================================================
# Total params: 4,742,688
# Trainable params: 4,742,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Entrenar y guardar
#En dir colocar la direccion de memoria donde se creara el directorio
#en save y save weigths colocar la direccion de memoria donde se guardara el modelo y sus pesos.
cnn.fit(imagen_entrenamiento, steps_per_epoch= pasos, epochs= epocas, validation_data= imagen_validacion, validation_steps=pasos_validacion)

dir = ''

if not os.path.exists(dir):
  os.mkdir(dir)

cnn.save('')
cnn.save_weights('')
# Out:
# 20/20 [==============================] - 1409s 70s/step - loss: 0.5590 - accuracy: 0.7127 - val_loss: 0.3306 - val_accuracy: 0.8857
# Epoch 2/100
# 20/20 [==============================] - 16s 794ms/step - loss: 0.3321 - accuracy: 0.8619 - val_loss: 0.2676 - val_accuracy: 0.9229
# Epoch 3/100
# 20/20 [==============================] - 19s 936ms/step - loss: 0.2675 - accuracy: 0.9033 - val_loss: 0.2374 - val_accuracy: 0.9329
